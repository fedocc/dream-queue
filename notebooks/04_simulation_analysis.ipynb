# %% [markdown]
# # Simulation Analysis
# Compare baseline and optimized simulation outputs.

# %%
import json
from pathlib import Path
summary = json.loads(Path('../outputs/reports/simulation_summary.json').read_text())
summary
